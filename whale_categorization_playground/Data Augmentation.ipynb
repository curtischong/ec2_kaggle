# %%
import numpy as np
import pandas as pd
import seaborn as sns
from glob import glob
from PIL import Image
import matplotlib.pylab as plt
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder
from sklearn.model_selection import train_test_split

import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# ## Importing the data

# %%
train_images = glob("../../.kaggle/competitions/whale-categorization-playground/train/*jpg")
test_images = glob("../../.kaggle/competitions/whale-categorization-playground/test/*jpg")
df = pd.read_csv("~/.kaggle/competitions/whale-categorization-playground/train.csv")

df["Image"] = df["Image"].map( lambda x : "../input/train/"+x)
ImageToLabelDict = dict( zip( df["Image"], df["Id"]))

# %%
SIZE = 64
#image are imported with a resizing and a black and white conversion
def ImportImage( filename):
    img = Image.open(filename).convert("LA").resize( (SIZE,SIZE))
    return np.array(img)[:,:,0]
train_img = np.array([ImportImage( img) for img in train_images])
x = train_img

# %% [markdown]
# ### Training sample distribution

# %%
print( "%d training images" %x.shape[0])

print( "Nbr of samples/class\tNbr of classes")
for index, val in df["Id"].value_counts().value_counts().sort_index().iteritems():
    print( "%d\t\t\t%d" %(index,val))
# Out:
# 9850 training images
# Nbr of samples/class	Nbr of classes
# 1			2220
# 2			1034
# 3			492
# 4			192
# 5			102
# 6			61
# 7			40
# 8			23
# 9			21
# 10			9
# 11			7
# 12			7
# 13			9
# 14			5
# 15			4
# 16			5
# 17			4
# 18			2
# 19			2
# 20			1
# 21			3
# 22			3
# 23			1
# 26			1
# 27			1
# 34			1
# 810			1

# %% [markdown]
# We read that the classes are very unbalanced: one class has ~800 samples while ~2000 have only one example in the training set. This calls for a lot of data augmentation.

# %% [markdown]
# #### One hot encoding on the labels
#
# Using a composition of a LabelEncoder and OneHotEncoder to one hot encode the target tail kinds.

# %%
class LabelOneHotEncoder():
    def __init__(self):
        self.ohe = OneHotEncoder()
        self.le = LabelEncoder()
    def fit_transform(self, x):
        features = self.le.fit_transform( x)
        return self.ohe.fit_transform( features.reshape(-1,1))
    def transform( self, x):
        return self.ohe.transform( self.la.transform( x.reshape(-1,1)))
    def inverse_tranform( self, x):
        return self.le.inverse_transform( self.ohe.inverse_tranform( x))
    def inverse_labels( self, x):
        return self.le.inverse_transform( x)

y = list(map(ImageToLabelDict.get, train_images))
lohe = LabelOneHotEncoder()
y_cat = lohe.fit_transform(y)

# %%
train_images
# Out:
# ['../../.kaggle/competitions/whale-categorization-playground/train/42cf9ddf.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/f80cf403.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/e5dfd9ab.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/8bb4b9a9.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/fc5a9810.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/773436f1.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/01e25788.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/e22715b2.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/90befe0d.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/7849d58b.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/b987724d.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/fc1882b1.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/75fcff8c.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/ddf1016b.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/46eeae34.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/e95061d7.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/0e8c8c34.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/d908b16f.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/d54be8e8.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/8827f71e.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/59642603.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/46b34507.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/0c222bc2.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/35dbbdd4.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/f9457b31.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/cf2515d0.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/f767cdfa.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/fd35f470.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/8f054a5b.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/110457ee.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/94fdd35d.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/61e03355.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/9aa693d3.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/42530ad2.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/7f448830.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/ecd014f1.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/c7c249d8.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/1a3e78ee.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/92518d0c.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/02cf6a52.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/90fb721a.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/d4f2b035.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/41a4f2e7.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/c1e4281e.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/19ff6ba0.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/fd77aed8.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/0fbba784.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/ba6d39ae.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/b74ced7a.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/89bd6fd9.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train
jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/2ed3d6b7.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/5ccf6e27.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/2f45cc3f.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/2d37fbf4.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/c694616d.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/0739fcdc.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/582c79a2.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/bdaeba7c.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/14424bad.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/d9fc6dfd.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/054c4923.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/ea5f45ca.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/03c6a5c0.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/32b6748b.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/90ee0de4.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/0fb7d824.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/0566b8e8.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/e1eba938.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/68383087.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/0375c878.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/30efc90e.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/91974c11.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/183cc72b.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/9c855d38.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/1351db8d.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/0317dee0.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/b1b9f9b9.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/9cfd9d9e.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/84280100.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/42e53534.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/e5003265.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/c968929b.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/8ae4e714.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/b89eaf81.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/e97c42f1.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/2119c8b2.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/d4a6ecc7.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/44f90b0e.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/3a97a929.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/d5b5f035.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/b5724cc4.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/5498c4d1.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/41f65e51.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/4661c676.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/608c2113.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/d13a4e4b.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/806cf583.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/9b244f1a.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/8e9e3b46.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/30ca0299.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/18a71917.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/69cb458b.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/b0412f41.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/bd699c43.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/be672908.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/826aa808.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/759e1682.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/be223239.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/67c96540.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/50228e30.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/abf14271.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/57c4b915.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/33ec74f3.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/a701a8e4.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/7899ccaf.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/e41762c4.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/43189ff2.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/4d9f10a3.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/5216ee0c.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/abca61c7.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/a46f9b05.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/38fa54af.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/214f651d.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/069e0d01.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/3f0279b3.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/d5e1a24e.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/84905fba.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/26bbcb80.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/40851751.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/4ac32a22.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/c1c44589.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/9947d920.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/3ef56efd.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/9d31f665.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/f00f98fb.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/9d1abcb7.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/76347ab3.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/5710a216.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/35e83b9b.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/633af56a.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/f2fe6436.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/945ff99a.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/c018a6ac.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/14fa05c4.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/84eec364.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/4dd2ca24.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/ca83d0ae.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/5f883b5d.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/9d70bd64.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/6481b5bd.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/d982ca00.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/7df67375.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/5bda8e2a.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/458011b4.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/c49810b8.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/f49ec25c.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/d81b0eac.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/c92d86b5.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/d9053660.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/e7df9a69.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/1d2c3bca.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/0a70aa2d.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/2426e8c3.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/6a5ddf81.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/2487e817.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/34a6b7c4.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/b2288bfd.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/b31fea6d.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/f6c4d521.jpg',
#  '../../.kaggle/competitions/whale-categorization-playground/train/71053f5a.jpg',
#  ...]

# %%
#constructing class weights
WeightFunction = lambda x : 1./x**0.75
ClassLabel2Index = lambda x : lohe.le.inverse_tranform( [[x]])
CountDict = dict( df["Id"].value_counts())
class_weight_dic = { lohe.le.transform( [image_name])[0] : WeightFunction(count) for image_name, count in CountDict.items()}
del CountDict
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-7d9ea0293ecc> in <module>()
#       3 ClassLabel2Index = lambda x : lohe.le.inverse_tranform( [[x]])
#       4 CountDict = dict( df["Id"].value_counts())
# ----> 5 class_weight_dic = { lohe.le.transform( [image_name])[0] : WeightFunction(count) for image_name, count in CountDict.items()}
#       6 del CountDict
#
# <ipython-input-14-7d9ea0293ecc> in <dictcomp>((image_name, count))
#       3 ClassLabel2Index = lambda x : lohe.le.inverse_tranform( [[x]])
#       4 CountDict = dict( df["Id"].value_counts())
# ----> 5 class_weight_dic = { lohe.le.transform( [image_name])[0] : WeightFunction(count) for image_name, count in CountDict.items()}
#       6 del CountDict
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/sklearn/preprocessing/label.pyc in transform(self, y)
#     131         if len(np.intersect1d(classes, self.classes_)) < len(classes):
#     132             diff = np.setdiff1d(classes, self.classes_)
# --> 133             raise ValueError("y contains new labels: %s" % str(diff))
#     134         return np.searchsorted(self.classes_, y)
#     135
#
# ValueError: y contains new labels: ['w_f78c287']

# %% [markdown]
# #### Some visualization

# %%
def plotImages( images_arr, n_images=4):
    fig, axes = plt.subplots(n_images, n_images, figsize=(12,12))
    axes = axes.flatten()
    for img, ax in zip( images_arr, axes):
        if img.ndim != 2:
            img = img.reshape( (SIZE,SIZE))
        ax.imshow( img, cmap="Greys_r")
        ax.set_xticks(())
        ax.set_yticks(())
    plt.tight_layout()

# %%
#plotting training images from training set after resizing and BW conversion
plotImages( x)

# %% [markdown]
# ### Image augmentation with Keras prebuilt

# %%
#use of an image generator for preprocessing and data augmentation
x = x.reshape( (-1,SIZE,SIZE,1))
input_shape = x[0].shape
x_train = x.astype("float32")
y_train = y_cat

image_gen = ImageDataGenerator(
    #featurewise_center=True,
    #featurewise_std_normalization=True,
    rescale=1./255,
    rotation_range=15,
    width_shift_range=.15,
    height_shift_range=.15,
    horizontal_flip=True)

#training the image preprocessing
image_gen.fit(x_train, augment=True)

#visualization of some images out of the preprocessing
#augmented_images, _ = next( image_gen.flow( x_train, y_train.toarray(), batch_size=4*4))
#plotImages( augmented_images)

# %% [markdown]
# ## Building and training model

# %%
batch_size = 128
num_classes = len(y_cat.toarray()[0])
epochs = 9

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')

model = Sequential()
model.add(Conv2D(48, kernel_size=(3, 3),
                 activation='relu',
                 input_shape=input_shape))
model.add(Conv2D(48, (3, 3), activation='sigmoid'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(48, (5, 5), activation='sigmoid'))
model.add(MaxPooling2D(pool_size=(3, 3)))
model.add(Dropout(0.33))
model.add(Flatten())
model.add(Dense(36, activation='sigmoid'))
model.add(Dropout(0.33))
model.add(Dense(36, activation='sigmoid'))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adadelta(),
              metrics=['accuracy'])
model.summary()
model.fit_generator(image_gen.flow(x_train, y_train.toarray(), batch_size=batch_size),
          steps_per_epoch=  x_train.shape[0]//batch_size,
          epochs=epochs,
          verbose=1,
          class_weight=class_weight_dic)

#score = model.evaluate(x_train, y_train, verbose=0)
#print('Training loss: {0:.4f}\nTraining accuracy:  {1:.4f}'.format(*score))
# Out:
# ('x_train shape:', (9850, 64, 64, 1))
# (9850, 'train samples')
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 62, 62, 48)        480
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 60, 60, 48)        20784
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 30, 30, 48)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 26, 26, 48)        57648
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 48)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8, 8, 48)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 3072)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 36)                110628
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 36)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 36)                1332
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 37
# =================================================================
# Total params: 190,909
# Trainable params: 190,909
# Non-trainable params: 0
# _________________________________________________________________
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-de4857558c74> in <module>()
#      29           epochs=epochs,
#      30           verbose=1,
# ---> 31           class_weight=class_weight_dic)
#      32
#      33 #score = model.evaluate(x_train, y_train, verbose=0)
#
# NameError: name 'class_weight_dic' is not defined

# %% [markdown]
# ### Predictions on test samples and export for submission

# %%
import warnings
from os.path import split

with open("sample_submission.csv","w") as f:
    with warnings.catch_warnings():
        f.write("Image,Id\n")
        warnings.filterwarnings("ignore",category=DeprecationWarning)
        for image in test_images:
            img = ImportImage( image)
            x = img.astype( "float32")
            #applying preprocessing to test images
            x = image_gen.standardize( x.reshape(1,SIZE,SIZE))
            
            y = model.predict_proba(x.reshape(1,SIZE,SIZE,1))
            predicted_args = np.argsort(y)[0][::-1][:5]
            predicted_tags = lohe.inverse_labels( predicted_args)
            image = split(image)[-1]
            predicted_tags = " ".join( predicted_tags)
            f.write("%s,%s\n" %(image, predicted_tags))
