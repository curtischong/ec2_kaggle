# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
train = pd.read_csv("~/.kaggle/competitions/sberbank-russian-housing-market/train.csv")
test = pd.read_csv("~/.kaggle/competitions/sberbank-russian-housing-market/test.csv")
macro = pd.read_csv("~/.kaggle/competitions/sberbank-russian-housing-market/macro.csv")
sample_submission = pd.read_csv("~/.kaggle/competitions/sberbank-russian-housing-market/sample_submission.csv")

# %%
macro.head()
# Out:
#     timestamp  oil_urals  gdp_quart  gdp_quart_growth  cpi  ppi  gdp_deflator  \
# 0  2010-01-01       76.1        NaN               NaN  NaN  NaN           NaN
# 1  2010-01-02       76.1        NaN               NaN  NaN  NaN           NaN
# 2  2010-01-03       76.1        NaN               NaN  NaN  NaN           NaN
# 3  2010-01-04       76.1        NaN               NaN  NaN  NaN           NaN
# 4  2010-01-05       76.1        NaN               NaN  NaN  NaN           NaN
#
#    balance_trade  balance_trade_growth  usdrub         ...          \
# 0            NaN                   NaN     NaN         ...
# 1            NaN                   NaN     NaN         ...
# 2            NaN                   NaN     NaN         ...
# 3            NaN                   NaN  29.905         ...
# 4            NaN                   NaN  29.836         ...
#
#    provision_retail_space_modern_sqm  turnover_catering_per_cap  \
# 0                              690.0                     6221.0
# ...

# %%
train.head()
# Out:
#    id   timestamp  full_sq  life_sq  floor  max_floor  material  build_year  \
# 0   1  2011-08-20       43     27.0    4.0        NaN       NaN         NaN
# 1   2  2011-08-23       34     19.0    3.0        NaN       NaN         NaN
# 2   3  2011-08-27       43     29.0    2.0        NaN       NaN         NaN
# 3   4  2011-09-01       89     50.0    9.0        NaN       NaN         NaN
# 4   5  2011-09-05       77     77.0    4.0        NaN       NaN         NaN
#
#    num_room  kitch_sq    ...      cafe_count_5000_price_2500  \
# 0       NaN       NaN    ...                               9
# 1       NaN       NaN    ...                              15
# 2       NaN       NaN    ...                              10
# 3       NaN       NaN    ...                              11
# 4       NaN       NaN    ...                             319
#
#   cafe_count_5000_price_4000 cafe_count_5000_price_high  \
# 0                          4                          0
# ...

# %%
def num_missing(x):
  return sum(x.isnull())

#Applying per column:
print ("Missing values per column:")
print (train.apply(num_missing, axis=0) )#axis=0 defines that function is to be applied on each column
# Out:
# Missing values per column:
# id                                           0
# timestamp                                    0
# full_sq                                      0
# life_sq                                   6383
# floor                                      167
# max_floor                                 9572
# material                                  9572
# build_year                               13605
# num_room                                  9572
# kitch_sq                                  9572
# state                                    13559
# product_type                                 0
# sub_area                                     0
# area_m                                       0
# raion_popul                                  0
# green_zone_part                              0
# indust_part                                  0
# children_preschool                           0
# preschool_quota                           6688
# ...

# %%
train.state = train.state.map(lambda x: 3 if(x == 33) else x)
train.build_year = train.build_year.map(lambda x: 2007 if(x == 20052009) else x)

# %%
selected_columns = ['full_sq', 'life_sq', 'floor', 'max_floor', 'build_year', 'num_room', 
                    'kitch_sq', 'state', 'price_doc']
corr = train[selected_columns].corr()
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)
# Out:
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family [u'sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
train.corr(['full_sq', 'life_sq', 'floor', 'max_floor', 'build_year', 'num_room', 
                    'kitch_sq', 'state', 'price_doc'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-ad97b024a2de> in <module>()
#       1 train.corr(['full_sq', 'life_sq', 'floor', 'max_floor', 'build_year', 'num_room',
# ----> 2                     'kitch_sq', 'state', 'price_doc'])
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in corr(self, method, min_periods)
#    4946                 min_periods = 1
#    4947             mat = _ensure_float64(mat).T
# -> 4948             corrf = nanops.get_corr_func(method)
#    4949             K = len(cols)
#    4950             correl = np.empty((K, K), dtype=float)
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/pandas/core/nanops.pyc in get_corr_func(method)
#     730         'spearman': _spearman
#     731     }
# --> 732     return _cor_methods[method]
#     733
#     734
#
# TypeError: unhashable type: 'list'

# %%
train.plot()
